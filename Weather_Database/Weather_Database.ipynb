# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key
import requests

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=991fbb3d5407d8a2a0a1a1ae6b92ac15'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | yar-sale
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | the valley
# Processing Record 7 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 1 | muisne
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | teguise
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | nakhon nayok
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | esperance
# Processing Record 17 of Set 1 | omaha
# Processing Record 18 of Set 1 | cayenne
# Processing Record 19 of Set 1 | ndago
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | noumea
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | gushikawa
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | pontianak
# Processing Record 27 of Set 1 | don benito
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | mannarakkat
# Processing Record 30 of Set 1 | brazzaville
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | wonthaggi
# Processing Record 33 of Set 1 | mitropoli
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | saint-pierre
# Processing Record 37 of Set 1 | hami
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | bintulu
# Processing Record 46 of Set 1 | imbituba
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | along
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | bowen
# Processing Record 2 of Set 2 | huangyan
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | igrim
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | vila franca do campo
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | ola
# Processing Record 10 of Set 2 | namibe
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | dalbandin
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | bedesa
# Processing Record 16 of Set 2 | mount isa
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | palmas de monte alto
# Processing Record 20 of Set 2 | samarai
# Processing Record 21 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 2 | vynohradove
# Processing Record 23 of Set 2 | inhambane
# Processing Record 24 of Set 2 | anshun
# Processing Record 25 of Set 2 | souillac
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | rosarito
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 30 of Set 2 | dingzhou
# Processing Record 31 of Set 2 | biak
# Processing Record 32 of Set 2 | fort nelson
# Processing Record 33 of Set 2 | nagato
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | port macquarie
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | jatai
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | ngunguru
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | valparaiso
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 2 | atikokan
# Processing Record 45 of Set 2 | san cristobal
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | alugan
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | outlook
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 3 | quincy
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | nuuk
# Processing Record 7 of Set 3 | asau
# Processing Record 8 of Set 3 | marcala
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | gravdal
# Processing Record 11 of Set 3 | kresttsy
# Processing Record 12 of Set 3 | lasa
# Processing Record 13 of Set 3 | san quintin
# Processing Record 14 of Set 3 | paisley
# Processing Record 15 of Set 3 | natal
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | saint anthony
# Processing Record 18 of Set 3 | plettenberg bay
# Processing Record 19 of Set 3 | awjilah
# Processing Record 20 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | honningsvag
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 3 | liwale
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | kangaatsiaq
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | acapulco
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | manzanillo
# Processing Record 34 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 3 | atar
# Processing Record 36 of Set 3 | lavrentiya
# Processing Record 37 of Set 3 | zaysan
# Processing Record 38 of Set 3 | zhanaozen
# Processing Record 39 of Set 3 | banda aceh
# Processing Record 40 of Set 3 | vardo
# Processing Record 41 of Set 3 | khorixas
# Processing Record 42 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 43 of Set 3 | hobyo
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | minab
# Processing Record 47 of Set 3 | adrar
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | ayan
# Processing Record 50 of Set 3 | tura
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | hit
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | faanui
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | lixourion
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | denia
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | tayturka
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | te anau
# Processing Record 18 of Set 4 | banjar
# Processing Record 19 of Set 4 | sorland
# Processing Record 20 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | korla
# Processing Record 23 of Set 4 | moses lake
# Processing Record 24 of Set 4 | verkhnyaya inta
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | linxia
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 29 of Set 4 | taltal
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | jizan
# Processing Record 33 of Set 4 | tahlequah
# Processing Record 34 of Set 4 | aykhal
# Processing Record 35 of Set 4 | kisangani
# Processing Record 36 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 4 | necochea
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | yazd
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | robertsport
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | kang
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | port hardy
# Processing Record 47 of Set 4 | caravelas
# Processing Record 48 of Set 4 | ambulu
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | yulara
# Processing Record 2 of Set 5 | okha
# Processing Record 3 of Set 5 | whitehorse
# Processing Record 4 of Set 5 | kaeo
# Processing Record 5 of Set 5 | shieli
# Processing Record 6 of Set 5 | labuhan
# Processing Record 7 of Set 5 | mangochi
# Processing Record 8 of Set 5 | karratha
# Processing Record 9 of Set 5 | jining
# Processing Record 10 of Set 5 | bethel
# Processing Record 11 of Set 5 | praia da vitoria
# Processing Record 12 of Set 5 | teahupoo
# Processing Record 13 of Set 5 | dawlatabad
# Processing Record 14 of Set 5 | sarangani
# Processing Record 15 of Set 5 | tambura
# Processing Record 16 of Set 5 | kholodnyy
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | north bend
# Processing Record 19 of Set 5 | egvekinot
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | maldonado
# Processing Record 22 of Set 5 | yenagoa
# Processing Record 23 of Set 5 | paita
# Processing Record 24 of Set 5 | nome
# Processing Record 25 of Set 5 | jalu
# Processing Record 26 of Set 5 | xichang
# Processing Record 27 of Set 5 | longview
# Processing Record 28 of Set 5 | sistranda
# Processing Record 29 of Set 5 | matagami
# Processing Record 30 of Set 5 | concarneau
# Processing Record 31 of Set 5 | canalete

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
